# %% [markdown]
# # Phase and Group Velocity and Dispersive and Non-Dispersive Waves
# ## Leslie Orozco, Phiona Vall, Ryan Williams

# %% [markdown]
# The group velocity is the speed of the envelope, overall shape of the wave's amplitudes. Group velocity is defined by the equation:
# \begin{align}
# v=\frac{d\omega(k)}{dk}
# \end{align}
# Where ω is the wave's angular frequency, and k is the angular wavenumber (magnitude of the wave vector).
#
# The Phase velocity of a wave is the rate at which the phase of the wave propagates in space, the speed of the individual ripples.
# Phase velocity is given in terms of wavelength or λ and time period T. The ratio between the speed of light c and the phase velocity v_p is known on the refraction index as:
# \begin{align}
# n = \frac{c}{v_p} = \frac{ck}{w}
# \end{align}
# For waves:
#
# \begin{align}
# k = \frac{2\pi}{\lambda} = \frac{2\pi\nu}{v_p} = \frac{w}{v_p}
# \end{align}
#
# For a non-dispersive sound wave traveling in air: the phase velocity is a constant and is the famous speed of sound, 343 m/s
#
#
# The function ω(k) is known as the dispersion relationship. The dispersion relationship relates the wavelength of the wave to its frequency.
#
# In a wave packet, the envelope travels at the group velocity and the ripples travel at the phase velocity
#
# For waves on a string, the group velocity is the same as the phase velocity.
#
# They both depend on the frequency and on the medium.
#
# If
# \begin{align}
# \frac{\omega}{k} > 0,
# \end{align}
# the wave moves to the right.
# If
# \begin{align}
# \frac{\omega}{k} < 0, \end{align} the wave moves to the left.
# The phase velocity of a wave in a plasma often exceeds the velocity of the light c. This does not violate the theory of relativity because an infinitely long wave train of constant amplitude cannot carry information.
#
#
# Cutoffs and Resonances
#
# A cutoff occurs in a plasma when the index of refraction goes to zero, when the wavelength becomes infinite. A resonance occurs when the index of refraction becomes infinite, when the wavelength becomes zero. A wave is generally rejected at a cutoff and absorbed at a resonance.

# %%
import numpy as np
import matplotlib.pyplot as plt 
import sympy as sym
from IPython.display import HTML
import matplotlib.animation as animation
sym.init_printing()
w = sym.Symbol('w')
k = sym.Symbol('k')
r = range(1,100)
w = [343*q for q in r]
plt.figure(figsize = (10,5))
plt.plot(r,w, color = 'red')
plt.xlabel('k (Wave Number)')
plt.ylabel('w (Angular Frequency)')
plt.title('Wave Number versus Frequency for a non-dispersive sound wave traveling in air')
plt.grid()
plt.show()

# %%
#calculating the derivative with respect to the wave number of the angular frequncy 
w = 343*k
sym.diff(w,k)
# Out:
# 343

# %% [markdown]
# \begin{align}
# V_g = \frac{dw}{dk} \\
# \end{align}
# For a non-dispersive sound wave traveling through air:
# \begin{align}
# V_g = 343 m/s \\
# \end{align}

# %%
#Plot the group velocity versus wave number for a non-dispersice wave traveling through air
dw = [343 for q in r]
plt.figure(figsize = (10,5))
plt.plot(r,dw, color = 'blue')
plt.xlabel('k (Wave Number)')
plt.ylabel('Vg (Group Velocity)')
plt.title('Group Velocity versus Wave Number for a non-dispersive sound wave traveling in air')
plt.grid()
plt.show()

# %%
w = [(9.8*q)**(1/2) for q in r]
plt.figure(figsize = (10,5))
plt.plot(r,w, color = 'red')
plt.xlabel('k (Wave Number)')
plt.ylabel('w (Angular Frequency)')
plt.title('Wave Number versus Frequency for a dispersive deep water wave')
plt.ylim([0,60])
plt.grid()
plt.show()

# %%
w = (9.8*k)**(1/2)
sym.diff(w,k)
# Out:
#                   -0.5
# 1.56524758424985⋅k

# %%
dw = [(9.8/2)*(9.8*q)**(-1/2) for q in r]
plt.figure(figsize = (10,5))
plt.plot(r,dw, color = 'blue')
plt.xlabel('k (Wave Number)')
plt.ylabel('Vg (Group Velocity)')
plt.title('Wave Number versus Group Velocity for a dispersive deep water wave')
plt.grid()
plt.show()

# %%
# These two lines tell matplotlib that we want our animation displayed
# with the html5 video method. If you do not do this, then the animation
# will not display in a notebook.
from matplotlib import rc
rc('animation', html='html5')

x = np.linspace(-10,10*np.pi,1000)
g = 9.8
k = 10 #controls amount of waves in the packet
c = 2.7 #controls wave speed
num_frames=100
speed=15.   # Speed of the animation in frames/sec. 
fig2 = plt.figure(figsize=(9,4))

#
# Setup the plotting limits.
plt.xlim(0,10*np.pi)
plt.ylim(-1.1,1.1)
# Here we setup the axes of the plot. We can set limits 
line, = plt.plot([],[],color="red")  # This is the empty plot line, in red.
#dot1, =  plt.plot([],[],'o',color="green",markersize=10)
#dot2, =  plt.plot([],[],'o',color="blue",markersize=15)

# Calling this after the plot was created, causes it NOT to be plotted.
# We don't need it plotted, since we just want to show the video
plt.close()
# initialization function: plot the background of each frame
def init():
    line.set_data([],[])
    return(line,)

# This is the animation routine. It paints the frame for time t.
def animate(t):
    y = np.exp(-(x-c*t)**2)*np.cos(k*(x-c*t))
    line.set_data(x,y)
    return(line,)

# We set a time array that is just long enough to have one complete wave cycle
# go by. We break it up into num_frame steps.
time = np.linspace(-1,4*np.pi,num_frames) 
#
# The next line computes the animation.
wave_ani = animation.FuncAnimation(fig2,animate,time,blit=True,interval=1000/speed,init_func=init)
# This line, takes the animation and outputs it. Since we asked for HTML5, we get an HTML5 video in our
# browser screen. Choose either the jshtml, which uses java script to display the animation, or
# use html5, which creates an html5 video file. 
HTML(wave_ani.to_jshtml())
# HTML(wave_ani.to_html5_video())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img1af290305d844d288ca6c6def609e16f">
#     <br>
#     <input id="_anim_slider1af290305d844d288ca6c6def609e16f" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim1af290305d844d288ca6c6def609e16f.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim1af290305d844d288ca6c6def609e16f.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim1af290305d844d288ca6c6def609e16f.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim1af290305d844d288ca6c6def609e16f.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim1af290305d844d288ca6c6def609e16f.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim1af290305d844d288ca6c6def609e16f.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim1af290305d844d288ca6c6def609e16f.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim1af290305d844d288ca6c6def609e16f.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim1af290305d844d288ca6c6def609e16f.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim1af290305d844d288ca6c6def609e16f.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select1af290305d844d288ca6c6def609e16f" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1af290305d844d288ca6c6def609e16f";
#     var slider_id = "_anim_slider1af290305d844d288ca6c6def609e16f";
#     var loop_select_id = "_anim_loop_select1af290305d844d288ca6c6def609e16f";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAHCZJREFUeJzt3XFs1PX9x/HXtTeYhCl0Umy9Gix3\
# 1ra0nnKVmmyOUs5GzY6hCEWj1aKnjmQRt2kTtYNkzBINm1vNssvIOGPWqmz2+EMq7ZgzI9PmJhc3\
# IcttFGnPA1p6bGoGhfN+f/jzfvv82rJCS7/X4/lITPr9fj/f9n3fnLln7tsrtlQqlRIAAADwv3Ks\
# HgAAAACZhUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAE\
# AACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACA\
# gUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAE\
# AACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAgUAEAACAwW71ANng8ssv14IFC6weAwAATIJDhw5p\
# cHDQ6jEsRSBOggULFigcDls9BgAAmAQej8fqESzHLWYAAAAYCEQAAAAYCEQAAAAYsjIQGxsblZ+f\
# r0WLFo16PJVK6Tvf+Y6cTqcqKyv13nvvpY8Fg0G5XC65XC4Fg8GpGhkAACBjZGUg3n///ers7Bzz\
# +K5duxSNRhWNRhUIBPToo49KkoaGhrRp0ya9++676unp0aZNm5RIJKZqbAAAgIyQlYF48803Ky8v\
# b8zjoVBI9913n2w2m6qrq3XixAnF43G9+eab8nq9ysvL09y5c+X1es8amgAAANkoKwPxv4nFYioq\
# KkpvOxwOxWKxMfcDAABcTC7Kv4OYSqVG7LPZbGPuH00gEFAgEJAkDQwMTO6AAAAAFroo30F0OBzq\
# 6+tLb/f396uwsHDM/aPx+/0Kh8MKh8OaN2/eBZ8ZAABgqlyUgejz+fTSSy8plUrpnXfe0WWXXaaC\
# ggLV1dVp9+7dSiQSSiQS2r17t+rq6qweFwAAYEpl5S3mtWvX6q233tLg4KAcDoc2bdqk06dPS5Ie\
# eeQR3XbbbXrjjTfkdDo1a9Ys/epXv5Ik5eXl6ZlnnlFVVZUkqbm5+awfdgEAAMhGttRov3iHc+Lx\
# ePi3mAEAyBK8rl+kt5gBAAAwNgIRAAAABgIRAAAABgIRAAAABgIRAAAABgIRAAAABgIRAAAABgIR\
# AAAABgIRAAAABgIRAAAABgIRAAAABgIRAAAABgIRAAAABgIRAAAABgIRAAAABgIRAAAAhqwMxM7O\
# TpWUlMjpdKqlpWXE8Q0bNsjtdsvtduuaa67RnDlz0sdyc3PTx3w+31SODQAAkBHsVg8w2ZLJpNav\
# X6+uri45HA5VVVXJ5/OprKwsvebHP/5x+uuf/exn2rdvX3r7kksuUSQSmdKZAQAAMknWvYPY09Mj\
# p9Op4uJizZgxQ/X19QqFQmOub2tr09q1a6dwQgAAgMyWdYEYi8VUVFSU3nY4HIrFYqOu/fDDD9Xb\
# 26tly5al9508eVIej0fV1dXq6Oi44PMCAABkmqy7xZxKpUbss9lso65tb2/XqlWrlJubm953+PBh\
# FRYW6uDBg1q2bJkqKiq0cOHCEecGAgEFAgFJ0sDAwCRNDwAAYL2sewfR4XCor68vvd3f36/CwsJR\
# 17a3t4+4vfzF2uLiYi1dutT4/cT/5Pf7FQ6HFQ6HNW/evEmaHgAAwHpZF4hVVVWKRqPq7e3V8PCw\
# 2tvbR/008t/+9jclEgnddNNN6X2JREKnTp2SJA0ODmrv3r3Gh1sAAAAuBll3i9lut6u1tVV1dXVK\
# JpNqbGxUeXm5mpub5fF40rHY1tam+vp64/bzgQMH9PDDDysnJ0efffaZmpqaCEQAA

# %%
# These two lines tell matplotlib that we want our animation displayed
# with the html5 video method. If you do not do this, then the animation
# will not display in a notebook.
from matplotlib import rc
rc('animation', html='html5')

x = np.linspace(0.,10*np.pi,1000)
g = 9.8
num_frames=100
speed=15.   # Speed of the animation in frames/sec. 
c = 2.7
fig2 = plt.figure(figsize=(9,5))

#
# Setup the plotting limits.
plt.xlim(0,10*np.pi)
plt.ylim(-1.1,1.1)
# Here we setup the axes of the plot. We can set limits 
line, = plt.plot([],[],color="red")  # This is the empty plot line, in red.
#dot1, =  plt.plot([],[],'o',color="green",markersize=10)
#dot2, =  plt.plot([],[],'o',color="blue",markersize=15)

# Calling this after the plot was created, causes it NOT to be plotted.
# We don't need it plotted, since we just want to show the video
plt.close()
# initialization function: plot the background of each frame
def init():
    line.set_data([],[])
    return(line,)

# This is the animation routine. It paints the frame for time t.
def animate(t):
    y = np.exp(-(x-c*t)**2)*np.cos(t*(x-c*t))
    line.set_data(x,y)
    return(line,)

# We set a time array that is just long enough to have one complete wave cycle
# go by. We break it up into num_frame steps.
time = np.linspace(-1,4*np.pi,num_frames) 
#
# The next line computes the animation.
wave_ani = animation.FuncAnimation(fig2,animate,time,blit=True,interval=1000/speed,init_func=init)
# This line, takes the animation and outputs it. Since we asked for HTML5, we get an HTML5 video in our
# browser screen. Choose either the jshtml, which uses java script to display the animation, or
# use html5, which creates an html5 video file. 
HTML(wave_ani.to_jshtml())
# HTML(wave_ani.to_html5_video())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img74de8c2a55594ad2bc77185d06c51826">
#     <br>
#     <input id="_anim_slider74de8c2a55594ad2bc77185d06c51826" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim74de8c2a55594ad2bc77185d06c51826.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim74de8c2a55594ad2bc77185d06c51826.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim74de8c2a55594ad2bc77185d06c51826.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim74de8c2a55594ad2bc77185d06c51826.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim74de8c2a55594ad2bc77185d06c51826.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim74de8c2a55594ad2bc77185d06c51826.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim74de8c2a55594ad2bc77185d06c51826.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim74de8c2a55594ad2bc77185d06c51826.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim74de8c2a55594ad2bc77185d06c51826.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim74de8c2a55594ad2bc77185d06c51826.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select74de8c2a55594ad2bc77185d06c51826" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img74de8c2a55594ad2bc77185d06c51826";
#     var slider_id = "_anim_slider74de8c2a55594ad2bc77185d06c51826";
#     var loop_select_id = "_anim_loop_select74de8c2a55594ad2bc77185d06c51826";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAHdBJREFUeJzt3X9sXfV9//GXEy8ZiLUkI0ntORUE\
# mzQJCW65blJpY4TgRm01M0oKYaiYBmrKkKZmP0ok2gyksRq1YuuWapo1NFxViktZG+cPCCRjDA2t\
# je6K1a2gyRtJSTwDCXG2thoxGH//6Bfv+/kmYYGEXOfyeEiWfM/5HPt9j250n7rnXqdhcnJyMgAA\
# 8H/NqPUAAABMLwIRAICCQAQAoCAQAQAoCEQAAAoCEQCAgkAEAKAgEAEAKAhEAAAKAhEAgIJABACg\
# IBABACgIRAAACgIRAICCQAQAoCAQAQAoCEQAAAoCEQCAgkAEAKAgEAEAKAhEAAAKAhEAgIJABACg\
# IBABACgIRAAACgIRAICCQAQAoCAQAQAoCEQAAAoCEQCAgkAEAKAgEAEAKAhEAAAKAhEAgIJABACg\
# IBABACgIRAAACgIRAICCQAQAoCAQAQAoCEQAAAoCEQCAQmOtB6gH5513Xs4///xajwEAnAJ79+7N\
# wYMHaz1GTQnEU+D8889PtVqt9RgAwClQqVRqPULNucQMAEBBIAIAUBCIAAAUBCIAAAWBCABAQSAC\
# AFAQiAAAFOoyEDds2JD58+fn4osvPub+ycnJ/M7v/E5aW1uzYsWK/OAHP5ja19/fn7a2trS1taW/\
# v/90jQwAMG3UZSDedNNN2bFjx3H3P/LIIxkeHs7w8HD6+vpy2223JUkOHTqUu+++O9///veze/fu\
# 3H333RkbGztdYwMATAt1GYiXXXZZ5s6de9z9g4ODufHGG9PQ0JBVq1bl8OHDGR0dzaOPPprOzs7M\
# nTs3c+bMSWdn55uGJgBAParLQPzfjIyMZOHChVO3W1paMjIyctztAADvJu/K/4t5cnLyqG0NDQ3H\
# 3X4sfX196evrS5IcOHDg1A4IAFBD78pXEFtaWrJv376p2/v3709zc/Nxtx9LT09PqtVqqtVq5s2b\
# 947PDABwurwrA7Grqyvf+MY3Mjk5me9973t573vfm6ampqxduzaPPfZYxsbGMjY2lsceeyxr166t\
# 9bgAAKdVXV5ivv766/PEE0/k4MGDaWlpyd13351XX301SfK5z30uH//4x/Pwww+ntbU1Z599dv76\
# r/86STJ37tx86UtfSkdHR5Jk8+bNb/phFwCAetQweaw33vGWVCqVVKvVWo8BAJwCntffpZeYAQA4\
# PoEIAEBBIAIAUBCIAAAUBCIAAAWBCABAQSACAFAQiAAAFAQiAAAFgQgAQEEgAgBQEIgAABQEIgAA\
# BYEIAEBBIAIAUBCIAAAUBCIAAAWBCABAQSACAFAQiAAAFAQiAACFugzEHTt2ZPHixWltbU1vb+9R\
# +zdu3Jj29va0t7fnoosuyrnnnju1b+bMmVP7urq6TufYAADTQmOtBzjVJiYmcvvtt2fnzp1paWlJ\
# R0dHurq6snTp0qk1f/InfzL1/Z//+Z/n6aefnrp91llnZWho6LTODAAwndTdK4i7d+9Oa2trFi1a\
# lFmzZmX9+vUZHBw87vqtW7fm+uuvP40TAgBMb3UXiCMjI1m4cOHU7ZaWloyMjBxz7Y9//OPs2bMn\
# V1xxxdS2V155JZVKJatWrcq2bdve8XkBAKaburvEPDk5edS2hoaGY64dGBjIunXrMnPmzKltzz//\
# fJqbm/Pcc8/liiuuyPLly3PhhRcedWxfX1/6+vqSJAcOHDhF0wMA1F7dvYLY0tKSffv2Td3ev39/\
# mpubj7l2YGDgqMvLb6xdtGhRLr/88uL9if+vnp6eVKvVVKvVzJs37xRNDwBQe3UXiB0dHRkeHs6e\
# PXsyPj6egYGBY34a+V//9V8zNjaWj3zkI1PbxsbGcuTIkSTJwYMH89RTTxUfbgEAe
